# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/weatherAUS.csv')
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %%
#Performing EDA
df.shape
# Out:
# (8425, 23)

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
# ...

# %%
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  8350.000000  8365.000000  8185.000000  4913.000000  4431.000000
# mean     13.193305    23.859976     2.805913     5.389395     7.632205
# std       5.403596     6.136408    10.459379     5.044484     3.896235
# min      -2.000000     8.200000     0.000000     0.000000     0.000000
# 25%       9.200000    19.300000     0.000000     2.600000     4.750000
# 50%      13.300000    23.300000     0.000000     4.600000     8.700000
# 75%      17.400000    28.000000     1.000000     7.000000    10.700000
# max      28.500000    45.500000   371.000000   145.000000    13.900000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    7434.000000   8349.000000   8318.000000  8366.000000  8323.000000
# mean       40.174469     13.847646     18.533662    67.822496    51.249790
# std        14.665721     10.174579      9.766986    16.833283    18.423774
# ...

# %%
#Exploring Data Variable
df.RainTomorrow.unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df.RainTomorrow.value_counts()
# Out:
# No     6195
# Yes    1991
# Name: RainTomorrow, dtype: int64

# %%
df.RainToday.unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df.RainToday.value_counts()
# Out:
# No     6195
# Yes    1990
# Name: RainToday, dtype: int64

# %%
#Checking Null Values
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# There are null values in most of the columns.

# %%
df["MinTemp"].fillna(df["MinTemp"].mode()[0],inplace=True)
df["MaxTemp"].fillna(df["MaxTemp"].mode()[0],inplace=True)
df["Rainfall"].fillna(df["Rainfall"].mode()[0],inplace=True)
df["Evaporation"].fillna(df["Evaporation"].mode()[0],inplace=True)
df["Sunshine"].fillna(df["Sunshine"].mode()[0],inplace=True)
df["WindGustDir"].fillna(df["WindGustDir"].mode()[0],inplace=True)
df["WindGustSpeed"].fillna(df["WindGustSpeed"].mode()[0],inplace=True)
df["WindDir9am"].fillna(df["WindDir9am"].mode()[0],inplace=True)
df["WindDir3pm"].fillna(df["WindDir3pm"].mode()[0],inplace=True)
df["WindSpeed9am"].fillna(df["WindSpeed9am"].mode()[0],inplace=True)
df["WindSpeed3pm"].fillna(df["WindSpeed3pm"].mode()[0],inplace=True)
df["Humidity9am"].fillna(df["Humidity9am"].mode()[0],inplace=True)
df["Humidity3pm"].fillna(df["Humidity3pm"].mode()[0],inplace=True)
df["Pressure9am"].fillna(df["Pressure9am"].mode()[0],inplace=True)
df["Pressure3pm"].fillna(df["Pressure3pm"].mode()[0],inplace=True)
df["Cloud9am"].fillna(df["Cloud9am"].mode()[0],inplace=True)
df["Cloud3pm"].fillna(df["Cloud3pm"].mode()[0],inplace=True)
df["Temp9am"].fillna(df["Temp9am"].mode()[0],inplace=True)
df["Temp3pm"].fillna(df["Temp3pm"].mode()[0],inplace=True)
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          4.0       0.0
# 1  2008-12-02   Albury      7.4     25.1       0.0          4.0       0.0
# 2  2008-12-03   Albury     12.9     25.7       0.0          4.0       0.0
# 3  2008-12-04   Albury      9.2     28.0       0.0          4.0       0.0
# 4  2008-12-05   Albury     17.5     32.3       1.0          4.0       0.0
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#df['RainToday'].fillna(df['RainToday'].mode()[0], inplace=True)
#df['RainTomorrow'].fillna(df['RainTomorrow'].mode()[0], inplace=True)
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          4.0       0.0
# 1  2008-12-02   Albury      7.4     25.1       0.0          4.0       0.0
# 2  2008-12-03   Albury     12.9     25.7       0.0          4.0       0.0
# 3  2008-12-04   Albury      9.2     28.0       0.0          4.0       0.0
# 4  2008-12-05   Albury     17.5     32.3       1.0          4.0       0.0
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.isnull().sum()
# Out:
# Date               0
# Location           0
# MinTemp            0
# MaxTemp            0
# Rainfall           0
# Evaporation        0
# Sunshine           0
# WindGustDir        0
# WindGustSpeed      0
# WindDir9am         0
# WindDir3pm         0
# WindSpeed9am       0
# WindSpeed3pm       0
# Humidity9am        0
# Humidity3pm        0
# Pressure9am        0
# Pressure3pm        0
# Cloud9am           0
# Cloud3pm           0
# Temp9am            0
# Temp3pm            0
# RainToday        240
# RainTomorrow     239
# dtype: int64

# %% [markdown]
# Now, There are no null values in our dataset.

# %%
df['RainTomorrow'].replace(to_replace='YES', value=1, inplace=True)
df['RainTomorrow'].replace(to_replace='NO', value=0, inplace=True)
df['RainTomorrow'].replace(to_replace='nan', value=0, inplace=True)

# %%
df['RainToday'].replace(to_replace='YES', value=1, inplace=True)
df['RainToday'].replace(to_replace='NO', value=0, inplace=True)
df['RainToday'].replace(to_replace='nan', value=0, inplace=True)

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          4.0       0.0
# 1  2008-12-02   Albury      7.4     25.1       0.0          4.0       0.0
# 2  2008-12-03   Albury     12.9     25.7       0.0          4.0       0.0
# 3  2008-12-04   Albury      9.2     28.0       0.0          4.0       0.0
# 4  2008-12-05   Albury     17.5     32.3       1.0          4.0       0.0
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# # Bivariate Analysis

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='MinTemp', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='MaxTemp', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='Evaporation', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='Sunshine', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='WindGustDir', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='WindGustSpeed', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='WindDir9am', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='WindDir3pm', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='WindSpeed9am', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='WindSpeed3pm', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='Humidity9am', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='Humidity3pm', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='WindDir3pm', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='Pressure9am', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='Pressure3pm', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='Cloud9am', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='Cloud3pm', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='Temp9am', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='Temp3pm', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %%
sns.countplot(df['RainTomorrow'],palette='coolwarm', hue='Rainfall', data=df)
# Out:
# <AxesSubplot:xlabel='RainTomorrow', ylabel='count'>

# %% [markdown]
# # Checking Correlation

# %%
dfcor=df.corr()
plt.figure(figsize=[12,10])
sns.heatmap(dfcor,annot=True)
plt.title("correlation matrix")
plt.show()

# %% [markdown]
# data is Fairly co-related.

# %%
# COnvert Date feature into datetime
df['Date']=pd.to_datetime(df['Date'])

# %%
df['year']=df['Date'].dt.year

# %%
df['month']=df['Date'].dt.month

# %%
df['day']=df['Date'].dt.day

# %%
df.drop('Date',axis=1,inplace=True)
df.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6          4.0       0.0           W
# 1   Albury      7.4     25.1       0.0          4.0       0.0         WNW
# 2   Albury     12.9     25.7       0.0          4.0       0.0         WSW
# 3   Albury      9.2     28.0       0.0          4.0       0.0          NE
# 4   Albury     17.5     32.3       1.0          4.0       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  Cloud9am  Cloud3pm  \
# 0           44.0          W        WNW  ...       1007.1       8.0       7.0
# 1           44.0        NNW        WSW  ...       1007.8       7.0       7.0
# 2           46.0          W        WSW  ...       1008.7       7.0       2.0
# 3           24.0         SE          E  ...       1012.8       7.0       7.0
# 4           41.0        ENE         NW  ...       1006.0       7.0       8.0
#
# ...

# %%
df1=df

# %%
df.dtypes
# Out:
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# year               int64
# month              int64
# day                int64
# dtype: object

# %%
from sklearn import preprocessing
import math
from sklearn import metrics 
le = preprocessing.LabelEncoder()
categorial_variables = ['Location','WindGustDir','WindDir9am','WindDir3pm','RainToday','RainTomorrow']
for i in categorial_variables:
    df[i] = le.fit_transform(df[i])
df.head(5)
df.to_csv('LabelEncoded_CleanData.csv')

# %%
df.dtypes
# Out:
# Location           int32
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir        int32
# WindGustSpeed    float64
# WindDir9am         int32
# WindDir3pm         int32
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday          int32
# RainTomorrow       int32
# year               int64
# month              int64
# day                int64
# dtype: object

# %% [markdown]
# Let's check the data distribution among all the columns.

# %%
df.plot(kind='density',subplots=True,layout=(6,11),sharex=False,legend=False,fontsize=1,figsize=(18,12))
plt.show()

# %% [markdown]
# we can see skewness in data for multiple columns, will handle the skewness in further steps.

# %% [markdown]
# # Checking outliers

# %%
df.plot(kind='box',subplots=True,layout=(17,6),figsize=(10,10))
# Out:
# Location            AxesSubplot(0.125,0.842624;0.110714x0.0373762)
# MinTemp          AxesSubplot(0.257857,0.842624;0.110714x0.0373762)
# MaxTemp          AxesSubplot(0.390714,0.842624;0.110714x0.0373762)
# Rainfall         AxesSubplot(0.523571,0.842624;0.110714x0.0373762)
# Evaporation      AxesSubplot(0.656429,0.842624;0.110714x0.0373762)
# Sunshine         AxesSubplot(0.789286,0.842624;0.110714x0.0373762)
# WindGustDir         AxesSubplot(0.125,0.797772;0.110714x0.0373762)
# WindGustSpeed    AxesSubplot(0.257857,0.797772;0.110714x0.0373762)
# WindDir9am       AxesSubplot(0.390714,0.797772;0.110714x0.0373762)
# WindDir3pm       AxesSubplot(0.523571,0.797772;0.110714x0.0373762)
# WindSpeed9am     AxesSubplot(0.656429,0.797772;0.110714x0.0373762)
# WindSpeed3pm     AxesSubplot(0.789286,0.797772;0.110714x0.0373762)
# Humidity9am         AxesSubplot(0.125,0.752921;0.110714x0.0373762)
# Humidity3pm      AxesSubplot(0.257857,0.752921;0.110714x0.0373762)
# ...

# %% [markdown]
# We have outtliers in our dataset. We will proceed further to remove oitliers.

# %%
df.skew()
# Out:
# Location         -0.050456
# MinTemp          -0.084104
# MaxTemp           0.391512
# Rainfall         13.200523
# Evaporation      13.812740
# Sunshine          0.606448
# WindGustDir       0.119640
# WindGustSpeed     0.786153
# WindDir9am        0.172792
# WindDir3pm       -0.119847
# WindSpeed9am      0.969604
# WindSpeed3pm      0.510765
# Humidity9am      -0.262767
# Humidity3pm       0.110858
# Pressure9am       0.171566
# Pressure3pm      -0.190150
# Cloud9am         -0.863322
# Cloud3pm         -0.804407
# Temp9am          -0.005160
# Temp3pm           0.412119
# RainToday         1.521128
# RainTomorrow      1.520255
# year              0.418663
# month             0.039388
# day               0.004260
# dtype: float64

# %% [markdown]
# Rainfall and Evapuration columns are not skewed.

# %%
num=[col for col in df.columns if df[col].dtypes!='O']
num
# Out:
# ['Location',
#  'MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustDir',
#  'WindGustSpeed',
#  'WindDir9am',
#  'WindDir3pm',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm',
#  'RainToday',
#  'RainTomorrow',
#  'year',
#  'month',
#  'day']

# %% [markdown]
# # Removing Outliers

# %%
for i in num:
    IQR= df[i].quantile(.75)-df[i].quantile(.25)
    lower=df[i].quantile(.25) - (1.5 * IQR)
    upper=df[i].quantile(.75) + (1.5 * IQR)
    df[i]=np.where(df[i]<lower,lower,df[i])
    df[i]=np.where(df[i]>upper,upper,df[i])

# %%
df.plot(kind='box',subplots=True,layout=(17,6),figsize=(10,10))
# Out:
# Location            AxesSubplot(0.125,0.842624;0.110714x0.0373762)
# MinTemp          AxesSubplot(0.257857,0.842624;0.110714x0.0373762)
# MaxTemp          AxesSubplot(0.390714,0.842624;0.110714x0.0373762)
# Rainfall         AxesSubplot(0.523571,0.842624;0.110714x0.0373762)
# Evaporation      AxesSubplot(0.656429,0.842624;0.110714x0.0373762)
# Sunshine         AxesSubplot(0.789286,0.842624;0.110714x0.0373762)
# WindGustDir         AxesSubplot(0.125,0.797772;0.110714x0.0373762)
# WindGustSpeed    AxesSubplot(0.257857,0.797772;0.110714x0.0373762)
# WindDir9am       AxesSubplot(0.390714,0.797772;0.110714x0.0373762)
# WindDir3pm       AxesSubplot(0.523571,0.797772;0.110714x0.0373762)
# WindSpeed9am     AxesSubplot(0.656429,0.797772;0.110714x0.0373762)
# WindSpeed3pm     AxesSubplot(0.789286,0.797772;0.110714x0.0373762)
# Humidity9am         AxesSubplot(0.125,0.752921;0.110714x0.0373762)
# Humidity3pm      AxesSubplot(0.257857,0.752921;0.110714x0.0373762)
# ...

# %% [markdown]
# All the outliers are removed.

# %%
df.skew()
# Out:
# Location        -0.050456
# MinTemp         -0.084104
# MaxTemp          0.371877
# Rainfall         1.189119
# Evaporation      0.535882
# Sunshine         0.606448
# WindGustDir      0.119640
# WindGustSpeed    0.539607
# WindDir9am       0.172792
# WindDir3pm      -0.119847
# WindSpeed9am     0.747611
# WindSpeed3pm     0.354269
# Humidity9am     -0.247090
# Humidity3pm      0.110858
# Pressure9am      0.197570
# Pressure3pm     -0.170952
# Cloud9am        -0.863322
# Cloud3pm        -0.804407
# Temp9am         -0.012282
# Temp3pm          0.372228
# RainToday        1.521128
# RainTomorrow     1.520255
# year             0.418663
# month            0.039388
# day              0.004260
# dtype: float64

# %% [markdown]
# We have removed the skewness.

# %%
from sklearn.preprocessing import power_transform
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %% [markdown]
# # Splitting Data into Dependent and Independent Variable

# %%
x=df.drop('RainTomorrow',axis=1)
y=df['RainTomorrow']

# %%
x.shape
# Out:
# (8425, 24)

# %%
y.shape
# Out:
# (8425,)

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=122,test_size=.3)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
predlr = lr.predict(x_test)
print(accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# 0.8057753164556962
# [[1744  124    0]
#  [ 289  293    0]
#  [  54   24    0]]
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.93      0.88      1868
#          1.0       0.66      0.50      0.57       582
#          2.0       0.00      0.00      0.00        78
#
#     accuracy                           0.81      2528
#    macro avg       0.50      0.48      0.48      2528
# weighted avg       0.77      0.81      0.78      2528

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.8081487341772152
# [[1744  121    3]
#  [ 290  291    1]
#  [  53   17    8]]
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.93      0.88      1868
#          1.0       0.68      0.50      0.58       582
#          2.0       0.67      0.10      0.18        78
#
#     accuracy                           0.81      2528
#    macro avg       0.73      0.51      0.55      2528
# weighted avg       0.79      0.81      0.79      2528

# %%
rc=RidgeClassifier()
rc.fit(x_train,y_train)
rc.score(x_train,y_train)
predrc=rc.predict(x_test)
print(accuracy_score(y_test,predrc))
print(confusion_matrix(y_test,predrc))
print(classification_report(y_test,predrc))
# Out:
# 0.8243670886075949
# [[1772   84   12]
#  [ 288  274   20]
#  [  27   13   38]]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.95      0.90      1868
#          1.0       0.74      0.47      0.58       582
#          2.0       0.54      0.49      0.51        78
#
#     accuracy                           0.82      2528
#    macro avg       0.71      0.64      0.66      2528
# weighted avg       0.81      0.82      0.81      2528

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.8322784810126582
# [[1663  195   10]
#  [ 190  385    7]
#  [  12   10   56]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.89      0.89      1868
#          1.0       0.65      0.66      0.66       582
#          2.0       0.77      0.72      0.74        78
#
#     accuracy                           0.83      2528
#    macro avg       0.77      0.76      0.76      2528
# weighted avg       0.83      0.83      0.83      2528

# %%
svc=SVC()
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.7389240506329114
# [[1868    0    0]
#  [ 582    0    0]
#  [  78    0    0]]
#               precision    recall  f1-score   support
#
#          0.0       0.74      1.00      0.85      1868
#          1.0       0.00      0.00      0.00       582
#          2.0       0.00      0.00      0.00        78
#
#     accuracy                           0.74      2528
#    macro avg       0.25      0.33      0.28      2528
# weighted avg       0.55      0.74      0.63      2528

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
rfc.score(x_train,y_train)
predrfc=rfc.predict(x_test)
print(accuracy_score(y_test,predrfc))
print(confusion_matrix(y_test,predrfc))
print(classification_report(y_test,predrfc))
# Out:
# 0.8852848101265823
# [[1803   63    2]
#  [ 200  377    5]
#  [  14    6   58]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.97      0.93      1868
#          1.0       0.85      0.65      0.73       582
#          2.0       0.89      0.74      0.81        78
#
#     accuracy                           0.89      2528
#    macro avg       0.88      0.79      0.82      2528
# weighted avg       0.88      0.89      0.88      2528

# %%
abc=AdaBoostClassifier()
abc.fit(x_train,y_train)
abc.score(x_train,y_train)
predabc=abc.predict(x_test)
print(accuracy_score(y_test,predabc))
print(confusion_matrix(y_test,predabc))
print(classification_report(y_test,predabc))
# Out:
# 0.8125
# [[1734  127    7]
#  [ 272  294   16]
#  [  27   25   26]]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.93      0.89      1868
#          1.0       0.66      0.51      0.57       582
#          2.0       0.53      0.33      0.41        78
#
#     accuracy                           0.81      2528
#    macro avg       0.68      0.59      0.62      2528
# weighted avg       0.80      0.81      0.80      2528

# %%
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
gbc.score(x_train,y_train)
predgbc=gbc.predict(x_test)
print(accuracy_score(y_test,predgbc))
print(confusion_matrix(y_test,predgbc))
print(classification_report(y_test,predgbc))
# Out:
# 0.8453322784810127
# [[1768   94    6]
#  [ 243  331    8]
#  [  29   11   38]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.95      0.90      1868
#          1.0       0.76      0.57      0.65       582
#          2.0       0.73      0.49      0.58        78
#
#     accuracy                           0.85      2528
#    macro avg       0.79      0.67      0.71      2528
# weighted avg       0.84      0.85      0.84      2528

# %% [markdown]
# Random Forest Classifier is giving max score.

# %% [markdown]
# # Hyper Tuning Model

# %%
params = {'n_estimators' : [100,150,200,300,500],
    'max_features' : [1, 2, 3, 4, 5],
    'max_samples' : [0.05, 0.1, 0.2, 0.5]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
GCV=GridSearchCV(rfc,param_grid=params,cv=5,n_jobs=-1,verbose=2)
GCV.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_features': [1, 2, 3, 4, 5],
#                          'max_samples': [0.05, 0.1, 0.2, 0.5],
#                          'n_estimators': [100, 150, 200, 300, 500]},
#              verbose=2)

# %%
GCV.best_estimator_
# Out:
# RandomForestClassifier(max_features=3, max_samples=0.5, n_estimators=150)

# %%
GCV.best_params_
# Out:
# {'max_features': 3, 'max_samples': 0.5, 'n_estimators': 150}

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)
accuracy_score(y_test,GCV_pred)
# Out:
# 0.8742088607594937

# %% [markdown]
# # Saving the model in pickle format

# %%
import joblib
joblib.dump(RandomForestClassifier,"Rainprediction.pkl")
# Out:
# ['Rainprediction.pkl']

# %% [markdown]
# Predicting the Rainfall

# %%
df1.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0       1.0     13.4     22.9       0.6          4.0       0.0         13.0
# 1       1.0      7.4     25.1       0.0          4.0       0.0         14.0
# 2       1.0     12.9     25.7       0.0          4.0       0.0         15.0
# 3       1.0      9.2     28.0       0.0          4.0       0.0          4.0
# 4       1.0     17.5     32.3       1.0          4.0       0.0         13.0
#
#    WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure3pm  Cloud9am  \
# 0           44.0        13.0        14.0  ...       1007.1       8.0
# 1           44.0         6.0        15.0  ...       1007.8       7.0
# 2           46.0        13.0        15.0  ...       1008.7       7.0
# 3           24.0         9.0         0.0  ...       1012.8       7.0
# 4           41.0         1.0         7.0  ...       1006.0       7.0
#
#    Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow    year  month  day
# ...

# %%
#Checking Null Values
df1.isnull().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# year             0
# month            0
# day              0
# dtype: int64

# %%
#Checking Correlation
dfcor=df1.corr()
plt.figure(figsize=[12,10])
sns.heatmap(dfcor,annot=True)
plt.title("correlation matrix")
plt.show()

# %%
df1.dtypes
# Out:
# Location         float64
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir      float64
# WindGustSpeed    float64
# WindDir9am       float64
# WindDir3pm       float64
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday        float64
# RainTomorrow     float64
# year             float64
# month            float64
# day              float64
# dtype: object

# %% [markdown]
# splitting data into dependent and independent variable

# %%
x=df1.drop('Rainfall',axis=1)
y=df1['Rainfall']

# %%
x.shape
# Out:
# (8425, 24)

# %%
y.shape
# Out:
# (8425,)

# %%
df1.plot(kind='box',subplots=True,layout=(17,6),figsize=(10,10))
# Out:
# Location            AxesSubplot(0.125,0.842624;0.110714x0.0373762)
# MinTemp          AxesSubplot(0.257857,0.842624;0.110714x0.0373762)
# MaxTemp          AxesSubplot(0.390714,0.842624;0.110714x0.0373762)
# Rainfall         AxesSubplot(0.523571,0.842624;0.110714x0.0373762)
# Evaporation      AxesSubplot(0.656429,0.842624;0.110714x0.0373762)
# Sunshine         AxesSubplot(0.789286,0.842624;0.110714x0.0373762)
# WindGustDir         AxesSubplot(0.125,0.797772;0.110714x0.0373762)
# WindGustSpeed    AxesSubplot(0.257857,0.797772;0.110714x0.0373762)
# WindDir9am       AxesSubplot(0.390714,0.797772;0.110714x0.0373762)
# WindDir3pm       AxesSubplot(0.523571,0.797772;0.110714x0.0373762)
# WindSpeed9am     AxesSubplot(0.656429,0.797772;0.110714x0.0373762)
# WindSpeed3pm     AxesSubplot(0.789286,0.797772;0.110714x0.0373762)
# Humidity9am         AxesSubplot(0.125,0.752921;0.110714x0.0373762)
# Humidity3pm      AxesSubplot(0.257857,0.752921;0.110714x0.0373762)
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=23,test_size=.3)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
predlr = lr.predict(x_test)
print(accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-e8cb57d846cb> in <module>
#       1 lr = LogisticRegression()
# ----> 2 lr.fit(x_train,y_train)
#       3 predlr = lr.predict(x_test)
#       4 print(accuracy_score(y_test,predlr))
#       5 print(confusion_matrix(y_test,predlr))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
# -> 1347         check_classification_targets(y)
#    1348         self.classes_ = np.unique(y)
#    1349
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
# ...

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-bfdca53ba3df> in <module>
#       1 knn=KNeighborsClassifier(n_neighbors=5)
# ----> 2 knn.fit(x_train,y_train)
#       3 knn.score(x_train,y_train)
#       4 predknn=knn.predict(x_test)
#       5 print(accuracy_score(y_test,predknn))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py in fit(self, X, y)
#     177             The fitted k-nearest neighbors classifier.
#     178         """
# --> 179         return self._fit(X, y)
#     180
#     181     def predict(self, X):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py in _fit(self, X, y)
#     379                     self.outputs_2d_ = True
#     380
# --> 381                 check_classification_targets(y)
#     382                 self.classes_ = []
# ...
